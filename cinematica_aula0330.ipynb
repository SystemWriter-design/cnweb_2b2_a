# %% [markdown]
# <a href="https://colab.research.google.com/github/SystemWriter-design/cnweb_2b2_a/blob/main/cinematica_aula0330.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fórmula da velocidade
# fonte: [https://www.todamateria.com.br/formulas-de-cinematica/]

# %%
def calculaVelMedia(deltaS, deltaT):
  velMedia = (deltaS/deltaT)
  return velMedia

# %% [markdown]
# ## Teste Serviço Nuvem: Velocidade Média

# %%
print("Vm=", calculaVelMedia(30, 15))
# Out:
# Vm= 2.0

# %% [markdown]
# # Fórmula da aceleração

# %%
def calculaAcelMedia(deltaS, deltaT):
  acelMedia = (deltaS/deltaT)
  return acelMedia

# %%
 print("Am=", calculaAcelMedia(30, 15))
# Out:
# Am= 2.0

# %% [markdown]
# # Fórmulas do Movimento Uniforme (MU)

# %%
def calculaMU(deltaS, deltaT):
  MU = (deltaS/deltaT)
  return MU

# %% [markdown]
# # Função horária do deslocamento

# %%
def calculaDesloc(inicialS, deltaT, v):
  d = inicialS + (v*deltaT)
  return d

# %% [markdown]
# ## Testes de Função : Horária de Deslocamento

# %%
print("Deslocamento= ",calculaDesloc(0, 15, 30))
# Out:
# Deslocamento=  450

# %% [markdown]
# # Fórmulas do Movimento Uniformemente Variado (MUV)

# %% [markdown]
# # Nova seção

# %% [markdown]
# ## Função horária da velocidade

# %% [markdown]
# ## Função horária da posição

# %% [markdown]
# # Equação de Torricelli

# %%
import math

def calTorricelli(vZero, acel, des):
  t=2*acel*des
  v=vZero+t
  res = round(math.sqrt(v), 2)
  return res

# %% [markdown]
# # Teste de Torricelli

# %%
print("Calculo de Torriceli: " ,calTorricelli(0, 1, 8))
# Out:
# Calculo de Torriceli:  4.0

# %% [markdown]
# # Fórmula do movimento vertical
